# %%
import os
from pathlib import Path

# Define the name of the root directory
ROOT_NAME = "EXPLib20"

# Find the root directory dynamically
current_dir = Path.cwd()
if current_dir.name == ROOT_NAME:
    root_dir = current_dir
else:
    for parent in current_dir.parents:
        if parent.name == ROOT_NAME:
            root_dir = parent
            break
    else:
        raise FileNotFoundError(f"Root directory named '{ROOT_NAME}' not found in the directory tree.")

# Change to the root directory
os.chdir(root_dir)
print(os.getcwd())
# Out:
# e:\RISE-OneDrive\RISE\SAFEXPLAIN-WP3 XAI - General\EXPLib20

# %%
from EXPLib.xai_library.data_explainers.data_utils import parse_json, analyze_bboxes, analyze_iou_correlations

output_folder = 'EXPLib/datasets/Camera/toy_model_v1_inference/pred_cropped'
image_path='EXPLib/datasets/Camera/toy_model_v1_inference/dev/images'
ground_truth_file='EXPLib/datasets/Camera/toy_model_v1_inference/dev/satellite_objdet_coco_dataset.json'
bbox_file='EXPLib/dl_component/CNN/Object_Detectors/toy_model_v1/toy_model_prediction.json'

# %%
bboxes=parse_json(bbox_file)
analyze_bboxes(bboxes, target_object_name='ground truth satellite')
# Out:
# ready for heatmap?
# ready for heatmap?
# ready for plot dist?
# ready for plot dist?

# %%
analyze_iou_correlations(bboxes)
# Out:
# Correlation between IoU and center_x: 0.004230973079885269
# Correlation between IoU and center_y: 0.006299876298559733
# Correlation between IoU and width: 0.2080700624532671
# Correlation between IoU and height: 0.2096864402501296
# Correlation between IoU and area: 0.16835585847141155
# Correlation between IoU and ratio: -0.03176517834423032
# Correlation between IoU and center_x_pred: 0.003517930078003913
# Correlation between IoU and center_y_pred: 0.011145232529519204
# Correlation between IoU and width_pred: 0.16337212645017848
# Correlation between IoU and height_pred: 0.1655129151235957
# Correlation between IoU and area_pred: 0.1285249371221747
# Correlation between IoU and ratio_pred: -0.030487951496752104
# Correlation between IoU and pred_score: 0.4520477303863567
